# %%
# import necessary library
import pandas as pd
import numpy as np
import os
import glob
from fuzzywuzzy import process
import re
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\s160555\AppData\Local\anaconda3\envs\geo_env\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#read the data
sdata=pd.read_csv('Z:/AT Data/Tableau Database/Tableau_Short_Term.csv')
sdata=sdata.dropna(subset=['Count'])
# Convert Date column to datetime
sdata.head()
# Out:
#    Loc_id  District           Intersection  Year Month       Day Weekday_Type  \
# 0    1001         1  4th and V St, Eureka   2014   Jul  Thursday      Weekday
# 1    1001         1  4th and V St, Eureka   2014   Aug  Saturday      Weekend
# 2    1001         1  4th and V St, Eureka   2014   Aug    Sunday      Weekend
# 3    1001         1  4th and V St, Eureka   2019   Aug  Thursday      Weekday
# 4    1001         1  4th and V St, Eureka   2019   Aug  Saturday      Weekend
#
#              Date       Hour        Mode   Direction  Count  Count_Type  \
# 0  7/31/2014 0:00  7AM - 7PM  Pedestrian  Northbound   3.33  Short term
# 1   8/2/2014 0:00  7AM - 7PM  Pedestrian  Northbound   4.50  Short term
# 2   8/3/2014 0:00  7AM - 7PM  Pedestrian  Northbound   3.25  Short term
# 3  8/15/2019 0:00  7AM - 7PM  Pedestrian  Northbound   2.25  Short term
# 4  8/17/2019 0:00  7AM - 7PM  Pedestrian  Northbound   2.83  Short term
#
#    No_Hrs_Data_collected
# 0                   12.0
# 1                   12.0
# 2                   12.0
# 3                   12.0
# 4                   12.0

# %%
# lets separate the d1 and d12 data
d1=sdata.loc[sdata['District']==1]
d1["Date"] = pd.to_datetime(d1["Date"], format="%m/%d/%Y", errors="coerce")
d1=d1.drop(['Month'],axis=1)
d1['Month'] = d1["Date"].dt.strftime("%b")
# Function to extract hours from the "Hour" column
def extract_hours(hour_range):
    # Use regex to extract time components safely
    match = re.findall(r"(\d{1,2}(?::\d{2})?[APap][Mm])", hour_range)
    
    if len(match) != 2:
        return None, None  # Return None if parsing fails

    # Convert AM/PM format to 24-hour format
    start_hour = pd.to_datetime(match[0], format="%I:%M%p" if ":" in match[0] else "%I%p").hour
    end_hour = pd.to_datetime(match[1], format="%I:%M%p" if ":" in match[1] else "%I%p").hour

    return start_hour, end_hour
# Apply function to extract start and end hours
d1[["Start_Hour", "End_Hour"]] = d1["Hour"].apply(lambda x: pd.Series(extract_hours(x)))
d1["no_hrs_collected"] = d1["End_Hour"] - d1["Start_Hour"]
d1.head()
# Out:
# C:\Users\s160555\AppData\Local\Temp\ipykernel_15784\2745908117.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   d1["Date"] = pd.to_datetime(d1["Date"], format="%m/%d/%Y", errors="coerce")
#    Loc_id  District           Intersection  Year       Day Weekday_Type Date  \
# 0    1001         1  4th and V St, Eureka   2014  Thursday      Weekday  NaT
# 1    1001         1  4th and V St, Eureka   2014  Saturday      Weekend  NaT
# 2    1001         1  4th and V St, Eureka   2014    Sunday      Weekend  NaT
# 3    1001         1  4th and V St, Eureka   2019  Thursday      Weekday  NaT
# 4    1001         1  4th and V St, Eureka   2019  Saturday      Weekend  NaT
#
#         Hour        Mode   Direction  Count  Count_Type  \
# 0  7AM - 7PM  Pedestrian  Northbound   3.33  Short term
# 1  7AM - 7PM  Pedestrian  Northbound   4.50  Short term
# 2  7AM - 7PM  Pedestrian  Northbound   3.25  Short term
# 3  7AM - 7PM  Pedestrian  Northbound   2.25  Short term
# 4  7AM - 7PM  Pedestrian  Northbound   2.83  Short term
#
#    No_Hrs_Data_collected Month  Start_Hour  End_Hour  no_hrs_collected
# 0                   12.0   NaN           7        19                12
# 1                   12.0   NaN           7        19                12
# 2                   12.0   NaN           7        19                12
# 3                   12.0   NaN           7        19                12
# 4                   12.0   NaN           7        19                12

# %%
d1_zero=d1.loc[d1['no_hrs_collected']==0]
d1_zero
# Out:
#       Loc_id  District        Intersection  Year       Day Weekday_Type Date  \
# 38      1008         1  Herrick SB Offramp  2021  Thursday      Weekday  NaT
# 39      1008         1  Herrick SB Offramp  2021    Friday      Weekday  NaT
# 40      1008         1  Herrick SB Offramp  2021  Saturday      Weekend  NaT
# 41      1008         1  Herrick SB Offramp  2021    Sunday      Weekend  NaT
# 42      1009         1            Hilfiker  2021  Thursday      Weekday  NaT
# ...      ...       ...                 ...   ...       ...          ...  ...
# 1116    1025         1           McCullens  2021    Sunday      Weekend  NaT
# 1129    1028         1           Pierson's  2021  Thursday      Weekday  NaT
# 1130    1028         1           Pierson's  2021    Friday      Weekday  NaT
# 1131    1028         1           Pierson's  2021  Saturday      Weekend  NaT
# 1132    1028         1           Pierson's  2021    Sunday      Weekend  NaT
#
#            Hour        Mode   Direction  Count  Count_Type  \
# 38    12AM-12AM  Pedestrian  Northbound   0.62  Short term
# 39    12AM-12AM  Pedestrian  Northbound   0.54  Short term
# 40    12AM-12AM  Pedestrian  Northbound   0.08  Short term
# 41    12AM-12AM  Pedestrian  Northbound   0.04  Short term
# 42    12AM-12AM  Pedestrian  Northbound   0.83  Short term
# ...         ...         ...         ...    ...         ...
# 1116  12AM-12AM     Bicycle  Southbound   0.71  Short term
# 1129  12AM-12AM     Bicycle  Southbound   0.54  Short term
# 1130  12AM-12AM     Bicycle  Southbound   0.54  Short term
# 1131  12AM-12AM     Bicycle  Southbound   0.33  Short term
# 1132  12AM-12AM     Bicycle  Southbound   0.42  Short term
#
#       No_Hrs_Data_collected Month  Start_Hour  End_Hour  no_hrs_collected
# 38                     24.0   NaN           0         0                 0
# 39                     24.0   NaN           0         0                 0
# 40                     24.0   NaN           0         0                 0
# 41                     24.0   NaN           0         0                 0
# 42                     24.0   NaN           0         0                 0
# ...                     ...   ...         ...       ...               ...
# 1116                   24.0   NaN           0         0                 0
# 1129                   24.0   NaN           0         0                 0
# 1130                   24.0   NaN           0         0                 0
# 1131                   24.0   NaN           0         0                 0
# 1132                   24.0   NaN           0         0                 0
#
# [160 rows x 17 columns]

# %%
d1_zero.Hour.unique()
# Out:
# array(['12AM-12AM'], dtype=object)

# %%
# it seems 12 AM to 12 AM date is wrong,, so we will replace the tme interval as 24 hours for the starting date
d1["no_hrs_collected"] = np.where(d1["no_hrs_collected"] == 0, 24, d1["no_hrs_collected"])
d1['Ave_Hourly_Volume']=(d1['Count']/d1["no_hrs_collected"]).round(2)
#d1['Hour'] = d1['Start_Hour'] + '-' + d1['End_Hour']
d1.head()
# Out:
#    Loc_id  District           Intersection  Year       Day Weekday_Type Date  \
# 0    1001         1  4th and V St, Eureka   2014  Thursday      Weekday  NaT
# 1    1001         1  4th and V St, Eureka   2014  Saturday      Weekend  NaT
# 2    1001         1  4th and V St, Eureka   2014    Sunday      Weekend  NaT
# 3    1001         1  4th and V St, Eureka   2019  Thursday      Weekday  NaT
# 4    1001         1  4th and V St, Eureka   2019  Saturday      Weekend  NaT
#
#         Hour        Mode   Direction  Count  Count_Type  \
# 0  7AM - 7PM  Pedestrian  Northbound   3.33  Short term
# 1  7AM - 7PM  Pedestrian  Northbound   4.50  Short term
# 2  7AM - 7PM  Pedestrian  Northbound   3.25  Short term
# 3  7AM - 7PM  Pedestrian  Northbound   2.25  Short term
# 4  7AM - 7PM  Pedestrian  Northbound   2.83  Short term
#
#    No_Hrs_Data_collected Month  Start_Hour  End_Hour  no_hrs_collected  \
# 0                   12.0   NaN           7        19                12
# 1                   12.0   NaN           7        19                12
# 2                   12.0   NaN           7        19                12
# 3                   12.0   NaN           7        19                12
# 4                   12.0   NaN           7        19                12
#
#    Ave_Hourly_Volume
# 0               0.28
# 1               0.38
# 2               0.27
# 3               0.19
# 4               0.24

# %%
d1['no_hrs_collected'].describe()
# Out:
# count    1148.000000
# mean       13.672474
# std         4.157833
# min        12.000000
# 25%        12.000000
# 50%        12.000000
# 75%        12.000000
# max        24.000000
# Name: no_hrs_collected, dtype: float64

# %%
d1['Ave_Hourly_Volume'].describe()
# Out:
# count    1148.000000
# mean        0.094591
# std         0.290069
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.080000
# max         3.900000
# Name: Ave_Hourly_Volume, dtype: float64

# %%
# lets separate the d12 data
d12=sdata.loc[sdata['District']==12]
# Convert the Date column to datetime
d12["Date_time"] = pd.to_datetime(d12["Date"], format="%m/%d/%Y %H:%M")
# Extract only the date part (without time)
d12["Date"] = d12["Date_time"].dt.date
# drop the datetime column
d12=d12.drop(['Date_time'],axis=1)
d12["Hour"] = pd.to_datetime(d12["Hour"], format="%I:%M %p").dt.strftime('%H:%M')
d12.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 4
#       2 d12=sdata.loc[sdata['District']==12]
#       3 # Convert the Date column to datetime
# ----> 4 d12["Date_time"] = pd.to_datetime(d12["Date"], format="%m/%d/%Y %H:%M")
#       5 # Extract only the date part (without time)
#       6 d12["Date"] = d12["Date_time"].dt.date
#
# File ~\AppData\Local\anaconda3\envs\geo_env\Lib\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File ~\AppData\Local\anaconda3\envs\geo_env\Lib\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# --> 247     cache_dates = convert_listlike(unique_dates, format)
#     248     # GH#45319
#     249     try:
#
# File ~\AppData\Local\anaconda3\envs\geo_env\Lib\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File ~\AppData\Local\anaconda3\envs\geo_env\Lib\site-packages\pandas\core\tools\datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "8/12/2022" doesn't match format "%m/%d/%Y %H:%M", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
d12.head()
# Out:
#       Loc_id  District    Intersection  Year Month     Day Weekday_Type  \
# 1148   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 1149   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 1150   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 1151   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 1152   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
#
#             Date                 Hour        Mode   Direction  Count  \
# 1148  2022-08-12  12:00 AM - 11:45 PM     Bicycle   Eastbound   0.00
# 1149  2022-08-12  12:00 AM - 11:45 PM     Bicycle  Northbound   1.50
# 1150  2022-08-12  12:00 AM - 11:45 PM     Bicycle  Southbound   2.00
# 1151  2022-08-12  12:00 AM - 11:45 PM     Bicycle   Westbound   0.04
# 1152  2022-08-12  12:00 AM - 11:45 PM  Pedestrian   Eastbound  12.96
#
#       Count_Type  No_Hrs_Data_collected
# 1148  Short term                   24.0
# 1149  Short term                   24.0
# 1150  Short term                   24.0
# 1151  Short term                   24.0
# 1152  Short term                   24.0

# %%
grouped = d12.groupby(
    ['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day', 
     'Weekday_Type', 'Date', 'Mode', 'Direction', 'Count_Type'])[['Hour']].agg(['min', 'max']).reset_index()
grouped.columns = ['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day', 
                   'Weekday_Type', 'Date', 'Mode', 'Direction', 'Count_Type', 
                   'Start_Hour', 'End_Hour']
#grouped["End_Hour"] = np.where(grouped["End_Hour"] == '23:45', '24', grouped["End_Hour"])
grouped['Hour'] = grouped['Start_Hour'] + '-' + grouped['End_Hour']
grouped=grouped.drop(['Start_Hour','End_Hour'],axis=1)
grouped.head()

# %%
grouped.Hour.unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 grouped.Hour.unique()
#
# NameError: name 'grouped' is not defined

# %%
grouped.dtypes
# Out:
# Loc_id           int64
# District         int64
# Intersection    object
# Year             int64
# Month           object
# Day             object
# Weekday_Type    object
# Date            object
# Mode            object
# Direction       object
# Count_Type      object
# Hour            object
# dtype: object

# %%
d12.isnull().sum()
# Out:
# Loc_id          0
# District        0
# Intersection    0
# Year            0
# Month           0
# Day             0
# Weekday_Type    0
# Date            0
# Hour            0
# Mode            0
# Direction       0
# Count           0
# Count_Type      0
# dtype: int64

# %%
d12.columns
# Out:
# Index(['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
#        'Weekday_Type', 'Date', 'Hour', 'Mode', 'Direction', 'Count',
#        'Count_Type'],
#       dtype='object')

# %%
# count how many 15 mins data was collected ffor each site, each day
d12_data_count=pd.DataFrame({'no_of_data_collected':d12.groupby(['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
       'Weekday_Type', 'Date', 'Mode', 'Direction','Count_Type'])['Loc_id'].count()}).reset_index()
d12_data_count['no_hrs_collected']=(d12_data_count['no_of_data_collected']/4).round(2)
# now sum the count
d12_count_sum=pd.DataFrame({'daily_count_sum':d12.groupby(['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
       'Weekday_Type', 'Date', 'Mode', 'Direction','Count_Type'])['Count'].sum()}).reset_index()
# join these two dataframe together
d12_data=pd.merge(d12_data_count,d12_count_sum, on=['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
       'Weekday_Type', 'Date', 'Mode', 'Direction','Count_Type'], how='inner')
d12_data1=pd.merge(d12_data,grouped, on=['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
       'Weekday_Type', 'Date', 'Mode', 'Direction','Count_Type'], how='inner')
d12_data1['Ave_Hourly_Volume']=(d12_data1['daily_count_sum']/d12_data1["no_hrs_collected"]).round(2)
d12_data1.head()
# Out:
#    Loc_id  District    Intersection  Year Month     Day Weekday_Type  \
# 0   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 1   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 2   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 3   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 4   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
#
#          Date        Mode   Direction  Count_Type  no_of_data_collected  \
# 0  2022-08-12     Bicycle   Eastbound  Short term                    96
# 1  2022-08-12     Bicycle  Northbound  Short term                    96
# 2  2022-08-12     Bicycle  Southbound  Short term                    96
# 3  2022-08-12     Bicycle   Westbound  Short term                    96
# 4  2022-08-12  Pedestrian   Eastbound  Short term                    96
#
#    no_hrs_collected  daily_count_sum         Hour  Ave_Hourly_Volume
# 0              24.0              0.0  00:00-23:45               0.00
# 1              24.0             36.0  00:00-23:45               1.50
# 2              24.0             48.0  00:00-23:45               2.00
# 3              24.0              1.0  00:00-23:45               0.04
# 4              24.0            311.0  00:00-23:45              12.96

# %%
# Function to convert 24-hour time to 12-hour format with AM/PM
def convert_to_12hr_format(hour):
    # Convert 24-hour time to 12-hour format
    return pd.to_datetime(hour, format='%H:%M').strftime('%I:%M %p')

# Apply the conversion to 'Hour' column
d12_data1[['Start_Hour_12', 'End_Hour_12']] = d12_data1['Hour'].str.split('-', expand=True)
d12_data1['Start_Hour_12'] = d12_data1['Start_Hour_12'].apply(convert_to_12hr_format)
d12_data1['End_Hour_12'] = d12_data1['End_Hour_12'].apply(convert_to_12hr_format)

# Combine the start and end hours in the desired format
d12_data1['Hour_Range'] =d12_data1['Start_Hour_12'] + ' - ' + d12_data1['End_Hour_12']
d12_data1.head()
# Out:
#    Loc_id  District    Intersection  Year Month     Day Weekday_Type  \
# 0   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 1   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 2   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 3   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
# 4   12001        12  PCH at 7th Ave  2022   Aug  Friday      Weekday
#
#          Date        Mode   Direction  Count_Type  no_of_data_collected  \
# 0  2022-08-12     Bicycle   Eastbound  Short term                    96
# 1  2022-08-12     Bicycle  Northbound  Short term                    96
# 2  2022-08-12     Bicycle  Southbound  Short term                    96
# 3  2022-08-12     Bicycle   Westbound  Short term                    96
# 4  2022-08-12  Pedestrian   Eastbound  Short term                    96
#
#    no_hrs_collected  daily_count_sum         Hour  Ave_Hourly_Volume  \
# 0              24.0              0.0  00:00-23:45               0.00
# 1              24.0             36.0  00:00-23:45               1.50
# 2              24.0             48.0  00:00-23:45               2.00
# 3              24.0              1.0  00:00-23:45               0.04
# 4              24.0            311.0  00:00-23:45              12.96
#
#   Start_Hour_12 End_Hour_12           Hour_Range
# 0      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 1      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 2      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 3      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 4      12:00 AM    11:45 PM  12:00 AM - 11:45 PM

# %%
outlier=d12_data1.loc[d12_data1['Ave_Hourly_Volume']>400]
outlier
# Out:
#      Loc_id  District    Intersection  Year Month       Day Weekday_Type  \
# 389   12007        12  PCH at Main St  2022   Jul    Friday      Weekday
# 390   12007        12  PCH at Main St  2022   Jul    Friday      Weekday
# 405   12007        12  PCH at Main St  2022   Jul  Saturday      Weekend
# 406   12007        12  PCH at Main St  2022   Jul  Saturday      Weekend
# 413   12007        12  PCH at Main St  2022   Jul    Sunday      Weekend
# 414   12007        12  PCH at Main St  2022   Jul    Sunday      Weekend
# 437   12007        12  PCH at Main St  2022   Jul   Tuesday      Weekday
#
#            Date        Mode   Direction  Count_Type  no_of_data_collected  \
# 389  2022-07-22  Pedestrian  Northbound  Short term                    96
# 390  2022-07-22  Pedestrian  Southbound  Short term                    96
# 405  2022-07-23  Pedestrian  Northbound  Short term                    96
# 406  2022-07-23  Pedestrian  Southbound  Short term                    96
# 413  2022-07-24  Pedestrian  Northbound  Short term                    96
# 414  2022-07-24  Pedestrian  Southbound  Short term                    96
# 437  2022-07-26  Pedestrian  Northbound  Short term                    96
#
#      no_hrs_collected  daily_count_sum         Hour  Ave_Hourly_Volume  \
# 389              24.0          11451.0  00:00-23:45             477.12
# 390              24.0           9636.0  00:00-23:45             401.50
# 405              24.0          17946.0  00:00-23:45             747.75
# 406              24.0          12959.0  00:00-23:45             539.96
# 413              24.0          15078.0  00:00-23:45             628.25
# 414              24.0          13989.0  00:00-23:45             582.88
# 437              24.0           9887.0  00:00-23:45             411.96
#
#     Start_Hour_12 End_Hour_12           Hour_Range
# 389      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 390      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 405      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 406      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 413      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 414      12:00 AM    11:45 PM  12:00 AM - 11:45 PM
# 437      12:00 AM    11:45 PM  12:00 AM - 11:45 PM

# %%
d12_data.shape, d12_count_sum.shape, d12_data_count.shape
# Out:
# ((888, 14), (888, 12), (888, 13))

# %%
d12_count['no_hrs_collected'].describe()
# Out:
# count    888.000000
# mean      20.990991
# std        7.752036
# min        0.500000
# 25%       23.875000
# 50%       24.000000
# 75%       24.000000
# max       24.000000
# Name: no_hrs_collected, dtype: float64

# %%
# lets check zero hours data 
d12_data1['Ave_Hourly_Volume'].describe()
# Out:
# count    888.000000
# mean      15.827849
# std       59.196641
# min        0.000000
# 25%        0.730000
# 50%        3.420000
# 75%        8.970000
# max      747.750000
# Name: Ave_Hourly_Volume, dtype: float64

# %%
d12_data.columns
# Out:
# Index(['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
#        'Weekday_Type', 'Date', 'Mode', 'Direction', 'Count_Type',
#        'no_of_data_collected', 'no_hrs_collected', 'daily_count_sum'],
#       dtype='object')

# %%
# select the columsn for final aggregation
d12_final=d12_data1[['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
       'Weekday_Type', 'Date', 'Hour_Range','Mode', 'Direction', 'Count_Type',
        'no_hrs_collected', 'Ave_Hourly_Volume']]
d12_final=d12_final.rename(columns={'Hour_Range':'Hour'})
d1_final=d1[['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
       'Weekday_Type', 'Date','Hour', 'Mode', 'Direction', 'Count_Type',
        'no_hrs_collected', 'Ave_Hourly_Volume']]
d1_12=pd.concat([d1_final,d12_final],axis=0)
d1_12=d1_12.rename(columns= {'Ave_Hourly_Volume': 'Count','no_hrs_collected': 'No_Hrs_Data_collected' })
# reorder
d1_12=d1_12[['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
       'Weekday_Type', 'Date', 'Hour', 'Mode', 'Direction', 'Count','Count_Type',
       'No_Hrs_Data_collected']]
d1_12.head()
# Out:
#    Loc_id  District           Intersection  Year Month       Day Weekday_Type  \
# 0    1001         1  4th and V St, Eureka   2014   Jul  Thursday      Weekday
# 1    1001         1  4th and V St, Eureka   2014   Aug  Saturday      Weekend
# 2    1001         1  4th and V St, Eureka   2014   Aug    Sunday      Weekend
# 3    1001         1  4th and V St, Eureka   2019   Aug  Thursday      Weekday
# 4    1001         1  4th and V St, Eureka   2019   Aug  Saturday      Weekend
#
#                   Date       Hour        Mode   Direction  Count  Count_Type  \
# 0  2014-07-31 00:00:00  7AM - 7PM  Pedestrian  Northbound   3.33  Short term
# 1  2014-08-02 00:00:00  7AM - 7PM  Pedestrian  Northbound   4.50  Short term
# 2  2014-08-03 00:00:00  7AM - 7PM  Pedestrian  Northbound   3.25  Short term
# 3  2019-08-15 00:00:00  7AM - 7PM  Pedestrian  Northbound   2.25  Short term
# 4  2019-08-17 00:00:00  7AM - 7PM  Pedestrian  Northbound   2.83  Short term
#
#    No_Hrs_Data_collected
# 0                   12.0
# 1                   12.0
# 2                   12.0
# 3                   12.0
# 4                   12.0

# %%
d1_12.columns
# Out:
# Index(['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
#        'Weekday_Type', 'Date', 'Hour', 'Mode', 'Direction', 'Count',
#        'Count_Type', 'No_Hrs_Data_collected'],
#       dtype='object')

# %%
d1_12.shape
# Out:
# (2036, 14)

# %%
d1_12.isnull().sum()
# Out:
# Loc_id                   0
# District                 0
# Intersection             0
# Year                     0
# Month                    0
# Day                      0
# Weekday_Type             0
# Date                     0
# Hour                     0
# Mode                     0
# Direction                0
# Count                    0
# Count_Type               0
# No_Hrs_Data_collected    0
# dtype: int64

# %%
d1_12.to_csv('Z:/AT Data/Tableau Database/normalized_d1_12_short_term_data.csv')

# %%
# end of the script

# %%
# read the normalized data
ndata=pd.read_csv('Z:/AT Data/Tableau Database/normalized_d1_12_short_term_data.csv')
ndata.head()
# Out:
#    Unnamed: 0  Loc_id  District           Intersection  Year Month       Day  \
# 0           0    1001         1  4th and V St, Eureka   2014   Jul  Thursday
# 1           1    1001         1  4th and V St, Eureka   2014   Aug  Saturday
# 2           2    1001         1  4th and V St, Eureka   2014   Aug    Sunday
# 3           3    1001         1  4th and V St, Eureka   2019   Aug  Thursday
# 4           4    1001         1  4th and V St, Eureka   2019   Aug  Saturday
#
#   Weekday_Type                 Date       Hour        Mode   Direction  Count  \
# 0      Weekday  2014-07-31 00:00:00  7AM - 7PM  Pedestrian  Northbound   3.33
# 1      Weekend  2014-08-02 00:00:00  7AM - 7PM  Pedestrian  Northbound   4.50
# 2      Weekend  2014-08-03 00:00:00  7AM - 7PM  Pedestrian  Northbound   3.25
# 3      Weekday  2019-08-15 00:00:00  7AM - 7PM  Pedestrian  Northbound   2.25
# 4      Weekend  2019-08-17 00:00:00  7AM - 7PM  Pedestrian  Northbound   2.83
#
#    Count_Type  No_Hrs_Data_collected
# 0  Short term                   12.0
# 1  Short term                   12.0
# 2  Short term                   12.0
# 3  Short term                   12.0
# 4  Short term                   12.0

# %%
# plot bike data
nbdata=ndata.loc[ndata['Mode']=='Bicycle']
# plot bike hourly average box plot by day of week
nbdata.head()
# Out:
#      Unnamed: 0  Loc_id  District           Intersection  Year Month  \
# 567         567    1001         1  4th and V St, Eureka   2014   Jul
# 568         568    1001         1  4th and V St, Eureka   2014   Aug
# 569         569    1001         1  4th and V St, Eureka   2014   Aug
# 570         570    1001         1  4th and V St, Eureka   2019   Aug
# 571         571    1001         1  4th and V St, Eureka   2019   Aug
#
#           Day Weekday_Type                 Date       Hour     Mode  \
# 567  Thursday      Weekday  2014-07-31 00:00:00  7AM - 7PM  Bicycle
# 568  Saturday      Weekend  2014-08-02 00:00:00  7AM - 7PM  Bicycle
# 569    Sunday      Weekend  2014-08-03 00:00:00  7AM - 7PM  Bicycle
# 570  Thursday      Weekday  2019-08-15 00:00:00  7AM - 7PM  Bicycle
# 571  Saturday      Weekend  2019-08-17 00:00:00  7AM - 7PM  Bicycle
#
#       Direction  Count  Count_Type  No_Hrs_Data_collected
# 567  Northbound   0.33  Short term                   12.0
# 568  Northbound   0.00  Short term                   12.0
# 569  Northbound   0.25  Short term                   12.0
# 570  Northbound   0.00  Short term                   12.0
# 571  Northbound   0.08  Short term                   12.0

# %%
# Order days correctly
days_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
nbdata["Day"] = pd.Categorical(nbdata["Day"], categories=days_order, ordered=True)

# Plot the box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x="Day", y="Count", data=nbdata)
plt.xlabel("Day of the Week")
plt.ylabel("Hourly Average Value")
plt.title("Box Plot of Hourly Averages Bike by Day of the Week")
plt.grid(True)
plt.show()
# Out:
# C:\Users\s160555\AppData\Local\Temp\ipykernel_15784\2443859639.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nbdata["Day"] = pd.Categorical(nbdata["Day"], categories=days_order, ordered=True)

# %%
# Order days correctly
months_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
                "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
nbdata["Month"] = pd.Categorical(nbdata["Month"], categories=months_order, ordered=True)

# Plot the box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x="Month", y="Count", data=nbdata)
plt.xlabel("Month of the Year")
plt.ylabel("Hourly Average Value")
plt.title("Box Plot of Hourly Averages Bike by Day of the Week")
plt.grid(True)
plt.show()
# Out:
# C:\Users\s160555\AppData\Local\Temp\ipykernel_15784\858806287.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nbdata["Month"] = pd.Categorical(nbdata["Month"], categories=months_order, ordered=True)

# %%
# plot ped data
npdata=ndata.loc[ndata['Mode']=='Pedestrian']
# plot bike hourly average box plot by day of week
npdata.head()
# Out:
#    Unnamed: 0  Loc_id  District           Intersection  Year Month       Day  \
# 0           0    1001         1  4th and V St, Eureka   2014   Jul  Thursday
# 1           1    1001         1  4th and V St, Eureka   2014   Aug  Saturday
# 2           2    1001         1  4th and V St, Eureka   2014   Aug    Sunday
# 3           3    1001         1  4th and V St, Eureka   2019   Aug  Thursday
# 4           4    1001         1  4th and V St, Eureka   2019   Aug  Saturday
#
#   Weekday_Type                 Date       Hour        Mode   Direction  Count  \
# 0      Weekday  2014-07-31 00:00:00  7AM - 7PM  Pedestrian  Northbound   3.33
# 1      Weekend  2014-08-02 00:00:00  7AM - 7PM  Pedestrian  Northbound   4.50
# 2      Weekend  2014-08-03 00:00:00  7AM - 7PM  Pedestrian  Northbound   3.25
# 3      Weekday  2019-08-15 00:00:00  7AM - 7PM  Pedestrian  Northbound   2.25
# 4      Weekend  2019-08-17 00:00:00  7AM - 7PM  Pedestrian  Northbound   2.83
#
#    Count_Type  No_Hrs_Data_collected
# 0  Short term                   12.0
# 1  Short term                   12.0
# 2  Short term                   12.0
# 3  Short term                   12.0
# 4  Short term                   12.0

# %%
# Order days correctly
days_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
npdata["Day"] = pd.Categorical(npdata["Day"], categories=days_order, ordered=True)

# Plot the box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x="Day", y="Count", data=npdata)
plt.xlabel("Day of the Week")
plt.ylabel("Hourly Average Value")
plt.title("Box Plot of Hourly Averages Ped by Day of the Week")
plt.grid(True)
plt.show()
# Out:
# C:\Users\s160555\AppData\Local\Temp\ipykernel_15784\2684889801.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   npdata["Day"] = pd.Categorical(npdata["Day"], categories=days_order, ordered=True)

# %%
# Order days correctly
months_order = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", 
                "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
npdata["Month"] = pd.Categorical(npdata["Month"], categories=months_order, ordered=True)

# Plot the box plot
plt.figure(figsize=(12, 6))
sns.boxplot(x="Month", y="Count", data=npdata)
plt.xlabel("Month of the Year")
plt.ylabel("Hourly Average Value")
plt.title("Box Plot of Hourly Averages ped by Day of the Week")
plt.grid(True)
plt.show()
# Out:
# C:\Users\s160555\AppData\Local\Temp\ipykernel_15784\1487350030.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   npdata["Month"] = pd.Categorical(npdata["Month"], categories=months_order, ordered=True)

# %%
# Clean the data further more
ndata1=ndata.loc[ndata['District']==1]
ndata1['Date']=pd.to_datetime(ndata1["Date"]).dt.date
ndata1.head()
# Out:
# C:\Users\s160555\AppData\Local\Temp\ipykernel_30380\2933208435.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndata1['Date']=pd.to_datetime(ndata1["Date"]).dt.date
#    Unnamed: 0  Loc_id  District           Intersection  Year Month       Day  \
# 0           0    1001         1  4th and V St, Eureka   2014   Jul  Thursday
# 1           1    1001         1  4th and V St, Eureka   2014   Aug  Saturday
# 2           2    1001         1  4th and V St, Eureka   2014   Aug    Sunday
# 3           3    1001         1  4th and V St, Eureka   2019   Aug  Thursday
# 4           4    1001         1  4th and V St, Eureka   2019   Aug  Saturday
#
#   Weekday_Type        Date       Hour        Mode   Direction  Count  \
# 0      Weekday  2014-07-31  7AM - 7PM  Pedestrian  Northbound   3.33
# 1      Weekend  2014-08-02  7AM - 7PM  Pedestrian  Northbound   4.50
# 2      Weekend  2014-08-03  7AM - 7PM  Pedestrian  Northbound   3.25
# 3      Weekday  2019-08-15  7AM - 7PM  Pedestrian  Northbound   2.25
# 4      Weekend  2019-08-17  7AM - 7PM  Pedestrian  Northbound   2.83
#
#    Count_Type  No_Hrs_Data_collected
# 0  Short term                   12.0
# 1  Short term                   12.0
# 2  Short term                   12.0
# 3  Short term                   12.0
# 4  Short term                   12.0

# %%
# Clean the data further more
ndata12=ndata.loc[ndata['District']==12]
ndata12['Date']=pd.to_datetime(ndata12["Date"]).dt.date
ndata12.head()
# Out:
# C:\Users\s160555\AppData\Local\Temp\ipykernel_30380\2001906352.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ndata12['Date']=pd.to_datetime(ndata12["Date"]).dt.date
#       Unnamed: 0  Loc_id  District    Intersection  Year Month     Day  \
# 1148           0   12001        12  PCH at 7th Ave  2022   Aug  Friday
# 1149           1   12001        12  PCH at 7th Ave  2022   Aug  Friday
# 1150           2   12001        12  PCH at 7th Ave  2022   Aug  Friday
# 1151           3   12001        12  PCH at 7th Ave  2022   Aug  Friday
# 1152           4   12001        12  PCH at 7th Ave  2022   Aug  Friday
#
#      Weekday_Type        Date                 Hour        Mode   Direction  \
# 1148      Weekday  2022-08-12  12:00 AM - 11:45 PM     Bicycle   Eastbound
# 1149      Weekday  2022-08-12  12:00 AM - 11:45 PM     Bicycle  Northbound
# 1150      Weekday  2022-08-12  12:00 AM - 11:45 PM     Bicycle  Southbound
# 1151      Weekday  2022-08-12  12:00 AM - 11:45 PM     Bicycle   Westbound
# 1152      Weekday  2022-08-12  12:00 AM - 11:45 PM  Pedestrian   Eastbound
#
#       Count  Count_Type  No_Hrs_Data_collected
# 1148   0.00  Short term                   24.0
# 1149   1.50  Short term                   24.0
# 1150   2.00  Short term                   24.0
# 1151   0.04  Short term                   24.0
# 1152  12.96  Short term                   24.0

# %%
ndata112.Hour.unique()
# Out:
# array(['7AM - 7PM', '12AM - 12PM', '12AM-12AM', '12:00 AM - 11:45 PM',
#        '11:30 PM - 11:45 PM', '12:00 AM - 11:15 PM',
#        '12:00 AM - 10:15 PM'], dtype=object)

# %%
# Now combine these two data format
ndata112=pd.concat([ndata1,ndata12],axis=0)
ndata112=ndata112.drop(['Unnamed: 0'],axis=1)
# Extract the starting hour from 'Hour' and convert to 24-hour format
# Extract the starting hour and AM/PM part separately
hour_extracted = ndata112["Hour"].str.extract(r'(\d{1,2}):?(\d{0,2})\s?(AM|PM)')

# Convert the first column to integer (hour) and the second column remains AM/PM
# Fill missing minutes with '00' and convert to integers
ndata112["Start_Hour"] = hour_extracted[0].astype(int)
ndata112["Start_Minute"] = hour_extracted[1].replace("", "0").astype(int)
ndata112["AM_PM"] = hour_extracted[2]

# Convert to 24-hour format correctly
def convert_to_24_hour(row):
    hour = row["Start_Hour"]
    minute = row["Start_Minute"]
    am_pm = row["AM_PM"]

    if am_pm == "AM" and hour == 12:
        hour = 0  # Midnight case
    elif am_pm == "PM" and hour != 12:
        hour += 12  # Convert PM to 24-hour format

    return f"{hour:02d}:{minute:02d}:00"

# Apply conversion
ndata112["Start_Time"] = ndata112.apply(convert_to_24_hour, axis=1)
# Create a new datetime column with date and extracted time
ndata112["Datetime"] = pd.to_datetime(ndata112["Date"].astype(str) + " " + ndata112["Start_Time"])
ndata112=ndata112.drop(["Date",'Start_Hour','Start_Minute','Start_Time'],axis=1)
ndata112=ndata112.rename(columns={'Datetime': 'Date'})
ndata112.head()
# Out:
#    Loc_id  District           Intersection  Year Month       Day Weekday_Type  \
# 0    1001         1  4th and V St, Eureka   2014   Jul  Thursday      Weekday
# 1    1001         1  4th and V St, Eureka   2014   Aug  Saturday      Weekend
# 2    1001         1  4th and V St, Eureka   2014   Aug    Sunday      Weekend
# 3    1001         1  4th and V St, Eureka   2019   Aug  Thursday      Weekday
# 4    1001         1  4th and V St, Eureka   2019   Aug  Saturday      Weekend
#
#         Hour        Mode   Direction  Count  Count_Type  \
# 0  7AM - 7PM  Pedestrian  Northbound   3.33  Short term
# 1  7AM - 7PM  Pedestrian  Northbound   4.50  Short term
# 2  7AM - 7PM  Pedestrian  Northbound   3.25  Short term
# 3  7AM - 7PM  Pedestrian  Northbound   2.25  Short term
# 4  7AM - 7PM  Pedestrian  Northbound   2.83  Short term
#
#    No_Hrs_Data_collected AM_PM                Date
# 0                   12.0    AM 2014-07-31 07:00:00
# 1                   12.0    AM 2014-08-02 07:00:00
# 2                   12.0    AM 2014-08-03 07:00:00
# 3                   12.0    AM 2019-08-15 07:00:00
# 4                   12.0    AM 2019-08-17 07:00:00

# %%
ndata112.Start_Hour.unique()
# Out:
# array([ 7,  0, 23], dtype=int64)

# %%
ndata1121=ndata112[['Loc_id', 'District', 'Intersection', 'Year', 'Month', 'Day',
       'Weekday_Type', 'Date', 'Hour', 'Mode', 'Direction', 'Count','Count_Type',
       'No_Hrs_Data_collected']]
ndata1121.head()
# Out:
#    Loc_id  District           Intersection  Year Month       Day Weekday_Type  \
# 0    1001         1  4th and V St, Eureka   2014   Jul  Thursday      Weekday
# 1    1001         1  4th and V St, Eureka   2014   Aug  Saturday      Weekend
# 2    1001         1  4th and V St, Eureka   2014   Aug    Sunday      Weekend
# 3    1001         1  4th and V St, Eureka   2019   Aug  Thursday      Weekday
# 4    1001         1  4th and V St, Eureka   2019   Aug  Saturday      Weekend
#
#                  Date       Hour        Mode   Direction  Count  Count_Type  \
# 0 2014-07-31 07:00:00  7AM - 7PM  Pedestrian  Northbound   3.33  Short term
# 1 2014-08-02 07:00:00  7AM - 7PM  Pedestrian  Northbound   4.50  Short term
# 2 2014-08-03 07:00:00  7AM - 7PM  Pedestrian  Northbound   3.25  Short term
# 3 2019-08-15 07:00:00  7AM - 7PM  Pedestrian  Northbound   2.25  Short term
# 4 2019-08-17 07:00:00  7AM - 7PM  Pedestrian  Northbound   2.83  Short term
#
#    No_Hrs_Data_collected
# 0                   12.0
# 1                   12.0
# 2                   12.0
# 3                   12.0
# 4                   12.0

# %%
# save the data
ndata1121.to_csv('Z:/AT Data/Processed_data/normalized_d1_12_short_term_data1.csv')

# %%
# end of script
